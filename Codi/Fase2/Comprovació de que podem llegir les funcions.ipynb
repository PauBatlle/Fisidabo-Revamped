# %%
import pickle
f = pickle.load(open("f.p", "rb"))
#gradf = pickle.load(open("gradf.p", "rb"))
dfx = pickle.load(open("dfx.p", "rb"))
dfy = pickle.load(open("dfy.p", "rb"))
dfxx = pickle.load(open("dfxx.p", "rb"))
dfxy = pickle.load(open("dfxy.p", "rb"))
dfyx = pickle.load(open("dfyx.p", "rb"))
dfyy = pickle.load(open("dfyy.p", "rb"))

# %%
from mpl_toolkits.mplot3d import Axes3D
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
ls
# Out:
# Comprovació de que podem llegir les funcions.ipynb*
# dfx.p*
# dfxx.p*
# dfxy.p*
# dfy.p*
# dfyx.p*
# dfyy.p*
# Exemple amb una funció coneguda.ipynb*
# f.p*
# grad_hess.py*
# Interpolant el llit.ipynb*
# Llit_Exemple/

# %%
Pos = np.load("Llit_Exemple/Tensor.npy")

# %%
Pos[:,:,0].shape
# Out:
# (218, 154)

# %%
M = np.zeros(Pos[:,:,0].shape)
for i in range(M.shape[0]):
    for j in range(M.shape[1]):
        M[i][j] = dfx(Pos[i,j,0],Pos[i,j,1])

# %%
# %matplotlib notebook
#Plot del llit en 3D
# Plot the surface.
#PLOT A SURFACE
fig = plt.figure('Llit')
ax = fig.gca(projection='3d')

fig.suptitle("dfx wannabe")
plt.xlabel("X (meters)")
plt.ylabel("Y (meters)")
ax.set_zlabel('Height (meters)')
ax.set_zlim(-1,0.1)

surf = ax.plot_surface(Pos[:,:,0], Pos[:,:,1], M, antialiased=True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
M2 = np.zeros(Pos[:,:,0].shape)
for i in range(M.shape[0]):
    for j in range(M.shape[1]):
        M2[i][j] = dfy(Pos[i,j,0],Pos[i,j,1])

# %%
# %matplotlib notebook
#Plot del llit en 3D
# Plot the surface.
#PLOT A SURFACE
fig = plt.figure('Llit')
ax = fig.gca(projection='3d')

fig.suptitle("dfy wannabe")
plt.xlabel("X (meters)")
plt.ylabel("Y (meters)")
ax.set_zlabel('Height (meters)')
ax.set_zlim(-1,0.1)

surf = ax.plot_surface(Pos[:,:,0], Pos[:,:,1], M2, antialiased=True)
# Out:
# <img src="data:image/png;base64,..." width="640">
