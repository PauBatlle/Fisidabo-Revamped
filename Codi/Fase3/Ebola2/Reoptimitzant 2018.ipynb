# %%
import numpy as np
import sympy as s
import pandas as pd
import matplotlib.pyplot as plt
from ebola_2 import ebola2
import distancia
from importlib import reload
from distancia import distancia as d

# %%
ls ..
# Out:
# Data/  Ebola2/  Ebola3/  Fent els gràfics.ipynb*  finals.csv*  README.md*

# %%
dades = [pd.read_csv("../Data/"+str(i)+"Cart.csv") for i in range(1,5)]

# %%
def dq(a,b):
    a1 = a['x'].as_matrix()
    a2 = a['y'].as_matrix()
    b1 = b['x'].as_matrix()
    b2 = b['y'].as_matrix()
    return np.linalg.norm(a1-b1)**2 + np.linalg.norm(a2-b2)**2

# %%
d1 = dades[0]
x01 = d1["x"][175]
y01 = d1["y"][175]
vx01 = d1["vx"][175]
vy01 = d1["vy"][175]
d2 = dades[1]
x02 = d2["x"][270]
y02 = d2["y"][270]
vx02 = d2["vx"][270]
vy02 = d2["vy"][270]
d3 = dades[2]
x03 = d3["x"][100]
y03 = d3["y"][100]
vx03 = d3["vx"][100]
vy03 = d3["vy"][100]
d4 = dades[3]
x04 = d4["x"][100]
y04 = d4["y"][100]
vx04 = d4["vx"][100]
vy04 = d4["vy"][100]
d1p = dades[0].iloc[175:838]
d2p = dades[1].iloc[270:1158]
d3p = dades[2].iloc[100:1063]
d4p = dades[3].iloc[100:429]
def nova_fitness(v):
    [c,k,sigma,mu] = v
    ebolaa = ebola2(c, k, sigma, mu, len(d1p), 1/180,x01,y01,vx01,vy01,"dummy",False)[['x','y']]
    ebolab = ebola2(c, k, sigma, mu, len(d2p), 1/180,x02,y02,vx02,vy02,"dummy",False)[['x','y']]
    ebolac = ebola2(c, k, sigma, mu, len(d3p), 1/180,x03,y03,vx03,vy03,"dummy",False)[['x','y']]
    ebolad = ebola2(c, k, sigma, mu, len(d4p), 1/180,x04,y04,vx04,vy04,"dummy",False)[['x','y']]
    return 0.25*(dq(ebolaa, d1p)+dq(ebolab,d2p)+dq(ebolac,d3p)+dq(ebolad,d4p))

# %%
[c,k,sigma,mu] = [0.8894148276526314,0.29164231949164177,1.0326906401025118,0.010368090273491459]

# %%
(c,k,sigma,mu) = (0.18122469690660842,
 1.100229883778495,
 1.0828552625100383,
 0.013203867928955651)

# %%
nova_fitness([c,k,sigma,mu])
# Out:
# 3.6279809903754483

# %%
from scipy.optimize import minimize
d2 = minimize(nova_fitness,[c,k,sigma,mu], method='Nelder-Mead', options={'disp': True})
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-a895d6b90e80> in <module>()
#       1 from scipy.optimize import minimize
# ----> 2 d2 = minimize(nova_fitness,[c,k,sigma,mu], method='Nelder-Mead', options={'disp': True})
#
# /usr/local/lib/python3.5/dist-packages/scipy/optimize/_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     473                       callback=callback, **options)
#     474     elif meth == 'nelder-mead':
# --> 475         return _minimize_neldermead(fun, x0, args, callback, **options)
#     476     elif meth == 'powell':
#     477         return _minimize_powell(fun, x0, args, callback, **options)
#
# /usr/local/lib/python3.5/dist-packages/scipy/optimize/optimize.py in _minimize_neldermead(func, x0, args, callback, maxiter, maxfev, disp, return_all, initial_simplex, xatol, fatol, **unknown_options)
#     546         xbar = numpy.add.reduce(sim[:-1], 0) / N
#     547         xr = (1 + rho) * xbar - rho * sim[-1]
# --> 548         fxr = func(xr)
#     549         doshrink = 0
#     550
#
# /usr/local/lib/python3.5/dist-packages/scipy/optimize/optimize.py in function_wrapper(*wrapper_args)
#     290     def function_wrapper(*wrapper_args):
#     291         ncalls[0] += 1
# --> 292         return function(*(wrapper_args + args))
#     293
#     294     return ncalls, function_wrapper
#
# <ipython-input-5-28cda99c3c01> in nova_fitness(v)
#      27     ebolaa = ebola2(c, k, sigma, mu, len(d1p), 1/180,x01,y01,vx01,vy01,"dummy",False)[['x','y']]
#      28     ebolab = ebola2(c, k, sigma, mu, len(d2p), 1/180,x02,y02,vx02,vy02,"dummy",False)[['x','y']]
# ---> 29     ebolac = ebola2(c, k, sigma, mu, len(d3p), 1/180,x03,y03,vx03,vy03,"dummy",False)[['x','y']]
#      30     ebolad = ebola2(c, k, sigma, mu, len(d4p), 1/180,x04,y04,vx04,vy04,"dummy",False)[['x','y']]
#      31     return 0.25*(dq(ebolaa, d1p)+dq(ebolab,d2p)+dq(ebolac,d3p)+dq(ebolad,d4p))
#
# /media/pau/HDD/Fisidabo_Final/Codi/Fase3/Ebola2/ebola_2.py in ebola2(c, k, sigma, mu, steps, timestep, x, y, vx, vy, take, escriu)
#      37         x1 = pos[t-1]
#      38         v1 = vel[t-1]
# ---> 39         a1 = Acc(x1,v1,c,k,s2,mu)
#      40         x2 = x1 + 0.5*v1*timestep
#      41         v2 = v1 + 0.5*a1*timestep
#
# /media/pau/HDD/Fisidabo_Final/Codi/Fase3/Ebola2/funcions_2.py in Acc(x, v, c, k, s2, mu)
#      60
#      61 def Acc(x, v, c, k, s2, mu):
# ---> 62     N, normal = Normal(x, v, c, k, s2) #mòdul i vector
#      63     gravity = np.array([0., 0., -m*g])
#      64     friction = Friction(v, N, mu)
#
# /media/pau/HDD/Fisidabo_Final/Codi/Fase3/Ebola2/funcions_2.py in Normal(x, v, c, k, s2)
#      36
#      37 def Normal(x, v, c, k, s2):
# ---> 38     r = Radius_tilla(x[0], x[1], s2)
#      39     v_r = (x[0]*v[0] + s2*x[1]*v[1])/r
#      40     dF = D_F(F(r,c,k),c)
#
# /media/pau/HDD/Fisidabo_Final/Codi/Fase3/Ebola2/funcions_2.py in Radius_tilla(x, y, s2)
#       5
#       6 def Radius_tilla(x, y, s2):
# ----> 7     return np.sqrt(x**2 + s2*y*y)
#       8
#       9 def Modul(v):
#
# KeyboardInterrupt:

# %%
d2

# %%
[c,k,sigma,mu] = d2.x

# %%
c,k,sigma,mu
# Out:
# (0.18122469690660842,
#  1.100229883778495,
#  1.0828552625100383,
#  0.013203867928955651)

# %% [markdown]
# # Plotem tots junts les dades vs els optims

# %%
# %matplotlib inline
def fes_me_els_grafics (c,k,sigma,mu):
    d1 = dades[0]
    x0 = dades[0]["x"][175]
    y0 = dades[0]["y"][175]
    vx0 = dades[0]["vx"][175]
    vy0 = dades[0]["vy"][175]
    timestep = 1/180
    steps = len(d1p)
    f, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, sharex='col', sharey='row')
    r = ebola2(c, k, sigma, mu, steps, timestep,x0,y0,vx0,vy0,True)
    ax1.plot(dades[0]['x'][175:837], dades[0]['y'][175:837])
    ax1.set_title("Take 1")
    ax1.plot(r['x'], r['y'], color = "red")
    ax1.axis("equal")
    #axarr[0,0].show()
    #plt.close()
    d2 = dades[1]
    x0 = d2["x"][270]
    y0 = d2["y"][270]
    vx0 = d2["vx"][270]
    vy0 = d2["vy"][270]
    timestep = 1/180
    steps = len(d2p)
    r = ebola2(c, k, sigma, mu, steps, timestep,x0,y0,vx0,vy0,True)
    ax2.plot(r['x'],r['y'],color = 'red')
    ax2.plot(dades[1]['x'][270:1158],dades[1]['y'][270:1158])
    ax2.set_title("Take 2")
    ax2.axis("equal")
    #axarr[0,1].show()
    #plt.close()
    d3 = dades[2]
    x0 = d3["x"][100]
    y0 = d3["y"][100]
    vx0 = d3["vx"][100]
    vy0 = d3["vy"][100]
    timestep = 1/180
    steps = len(d3p)
    r = ebola2(c, k, sigma, mu, steps, timestep,x0,y0,vx0,vy0,True)
    ax3.plot(r['x'], r['y'], color = "red")
    ax3.plot(d3['x'][100:1063], d3['y'][100:1063])
    ax3.axis("equal")
    ax3.set_title("Take 3")
    #plt.show()
    #axarr[1,1].close()
    d4 = dades[3]
    x0 = d4["x"][100]
    y0 = d4["y"][100]
    vx0 = d4["vx"][100]
    vy0 = d4["vy"][100]
    timestep = 1/180
    steps = len(d4p)
    r = ebola2(c, k, sigma, mu, steps, timestep,x0,y0,vx0,vy0,True)
    ax4.plot(r['x'], r['y'], color = "red")
    ax4.set_title("Take 4")
    ax4.plot(d4['x'][100:429], d4['y'][100:429])
    ax4.axis("equal")
    """
    leg = plt.legend(["real", "fake"])
    if leg:
        leg.draggable()
    """
    plt.show()
    plt.close()

# %%
c,k,sigma,mu
# Out:
# (0.8894148276526314,
#  0.29164231949164177,
#  1.0326906401025118,
#  0.010368090273491459)

# %%
fes_me_els_grafics(1.4230, 0.2021, 1.1220, 0.0093)

# %%
fes_me_els_grafics(c,k,sigma,mu)

# %%
fes_me_els_grafics(c,k,sigma,mu)
