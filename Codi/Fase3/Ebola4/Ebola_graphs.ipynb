# %%
# %run fit.py

# %%
import matplotlib.pyplot as plt
# %matplotlib
# Out:
# Using matplotlib backend: TkAgg

# %%
# %matplotlib notebook
[sigma,mu,nu,s0] = [ 1.04743081,  0.00941941,  0.01616359, -3.92741678]
#grafic1
c = 1.8
k = 0.44
circle1 = plt.Circle((0, 0), 0.085, color='r')
fig, ax = plt.subplots() # note we must use plt.subplots, not plt.subplot
# (or if you have an existing figure)
# fig = plt.gcf()
# ax = fig.gca()

ax.add_artist(circle1)
plt.axis('equal')
plt.xlim(-0.1,0.1)
comu = [False, True, c,k,sigma,mu,nu,s0]
A = ebola4(*comu, x01,y01,vx01,vy01,len(d1p)-1)
B = ebola4(True, True, c, k, 0.99964116,  0.4002429, -1, -1, x01,y01,vx01,vy01,len(d1p)-1)
plt.plot(d1p['x'],d1p['y'], )
plt.plot(B[:,0], B[:,1], c = 'g')
plt.plot(A[:,0], A[:,1], c = 'y')

plt.legend(["Observed trajectory", "Point particle best fit", "Rolling sphere best fit"])
plt.title("Optimization results in the simulated trampoline")
# Out:
# ...
# Text(0.5,1,'Optimization results in the simulated trampoline')

# %%
def ploteja3(c,k,sigma,mu,nu,s1,s2,s3,s4):
    comu = [False, True, c,k,sigma,mu,nu]
    f, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, sharex='col', sharey='row')
    plt.axis('equal')
    plt.xlim(-0.1,0.1)
    A = ebola4(*comu, s1, x01,y01,vx01,vy01,len(d1p)-1)
    B = ebola4(*comu, s2, x02,y02,vx02,vy02,len(d2p)-1)
    C = ebola4(*comu, s3,x03,y03,vx03,vy03,len(d3p)-1)
    D = ebola4(*comu, s4, x04,y04,vx04,vy04,len(d4p)-1)
    print(dq(A,d1p))
    print(dq(B,d2p))
    print(dq(C,d3p))
    print(dq(D,d4p))
    
    print("fitness ", 0.25*(dq(A,d1p)+dq(B,d2p)+dq(C,d3p)+dq(D,d4p)))
    ax1.plot(d1p['x'],d1p['y'])
    ax1.plot(A[:,0], A[:,1], c = 'r')
    ax2.plot(d2p['x'],d2p['y'])
    ax2.plot(B[:,0], B[:,1], c = 'r')
    
    ax3.plot(d3p['x'],d3p['y'])
    ax3.plot(C[:,0], C[:,1], c = 'r')
    ax4.plot(d4p['x'],d4p['y'])
    ax4.plot(D[:,0], D[:,1], c = 'r')

    """
    ax1.set_xlim(-0.1,0.1)
    ax1.set_ylim(-0.1,0.1)
    ax2.set_xlim(-0.1,0.1)
    ax2.set_ylim(-0.1,0.1)
    ax3.set_xlim(-0.1,0.1)
    ax3.set_ylim(-0.1,0.1)
    ax4.set_xlim(-0.1,0.1)
    ax4.set_ylim(-0.1,0.1)
    """

# %%
ploteja3(2.40447123,  0.4334582 ,  1.03953586,  0.00563565,  0.04651377,
       -4.14025028, -5.08209939, -5.04849853, -3.87803024)
# Out:
# <img src="data:image/png;base64,..." width="934.9999860674145">
# 4.09841663733
# 1.25592060169
# 1.78442023331
# 0.235207132695
# fitness  1.84349115126

# %%
def ploteja2(c, k, sigma, mu):
    comu = [True, True, c, k, sigma, mu, 0,0]
    f, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, sharex='col', sharey='row')
    plt.axis('equal')
    plt.xlim(-0.1,0.1)
    A = ebola4(*comu, x01,y01,vx01,vy01,len(d1p)-1)
    B = ebola4(*comu, x02,y02,vx02,vy02,len(d2p)-1)
    C = ebola4(*comu, x03,y03,vx03,vy03,len(d3p)-1)
    D = ebola4(*comu, x04,y04,vx04,vy04,len(d4p)-1)
    
    
    print("fitness ", 0.25*(dq(A,d1p)+dq(B,d2p)+dq(C,d3p)+dq(D,d4p)))
    
    print(dq(A,d1p))
    print(dq(B,d2p))
    print(dq(C,d3p))
    print(dq(D,d4p))
    
    ax1.plot(d1p['x'],d1p['y'])
    ax1.plot(A[:,0], A[:,1], c = 'r')
    ax2.plot(d2p['x'],d2p['y'])
    ax2.plot(B[:,0], B[:,1], c = 'r')
    
    ax3.plot(d3p['x'],d3p['y'])
    ax3.plot(C[:,0], C[:,1], c = 'r')
    ax4.plot(d4p['x'],d4p['y'])
    ax4.plot(D[:,0], D[:,1], c = 'r')

    """
    ax1.set_xlim(-0.1,0.1)
    ax1.set_ylim(-0.1,0.1)
    ax2.set_xlim(-0.1,0.1)
    ax2.set_ylim(-0.1,0.1)
    ax3.set_xlim(-0.1,0.1)
    ax3.set_ylim(-0.1,0.1)
    ax4.set_xlim(-0.1,0.1)
    ax4.set_ylim(-0.1,0.1)
    """

# %%
ploteja2(0.246260,0.832503,1.083962,0.012376)
# Out:
# <img src="data:image/png;base64,..." width="1019.9999848008158">
# fitness  3.65464827759
# 6.38940249292
# 3.20240482501
# 3.92872524335
# 1.0980605491

# %%
v = [0.246260,0.832503,1.083962,0.012376, 2.40447123,  0.4334582 ,  1.03953586,  0.00563565,  0.04651377,
       -4.14025028, -5.08209939, -5.04849853, -3.87803024]
[c2, k2, sigma2,mu2,c3,k3,sigma3,mu3,nu,s1,s2,s3,s4] = v

# %%
    comu2 = [True, True, c2, k2, sigma2, mu2, 0,0]
    A2 = ebola4(*comu2, x01,y01,vx01,vy01,len(d1p)-1)
    B2 = ebola4(*comu2, x02,y02,vx02,vy02,len(d2p)-1)
    C2 = ebola4(*comu2, x03,y03,vx03,vy03,len(d3p)-1)
    D2 = ebola4(*comu2, x04,y04,vx04,vy04,len(d4p)-1)
    
    
    comu3 = [False, True, c3,k3,sigma3,mu3,nu]
    A3 = ebola4(*comu3, s1, x01,y01,vx01,vy01,len(d1p)-1)
    B3 = ebola4(*comu3, s2, x02,y02,vx02,vy02,len(d2p)-1)
    C3 = ebola4(*comu3, s3,x03,y03,vx03,vy03,len(d3p)-1)
    D3 = ebola4(*comu3, s4, x04,y04,vx04,vy04,len(d4p)-1)

# %%
f, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, sharex='all', sharey='all')
plt.axis('equal')
plt.xlim(-0.1,0.1)
color_real = 'b'
color_point = 'g'
color_sphere = 'y'
kk = 0.5
circle1 = plt.Circle((0, 0), 0.08, color='r')
circle2 = plt.Circle((0, 0), 0.08, color='r')
circle3 = plt.Circle((0, 0), 0.08, color='r')
circle4 = plt.Circle((0, 0), 0.08, color='r')



ax1.plot(d1p['x'],d1p['y'], c = color_real)
ax1.plot(A2[:,0], A2[:,1], c = color_point)
ax1.plot(A3[:,0], A3[:,1], c = color_sphere)
ax1.set_title("Take 1")
ax1.add_artist(circle1)
ax1.legend(["Observed trajectory", "Point particle best fit", "Rolling sphere best fit"])

ax2.plot(d2p['x'],d2p['y'], c= color_real)
ax2.plot(B2[:,0], B2[:,1], c = color_point)
ax2.plot(B3[:,0], B3[:,1], c = color_sphere)
ax2.set_title("Take 2")
ax2.add_artist(circle2)
ax2.legend(["Observed trajectory", "Point particle best fit", "Rolling sphere best fit"])


ax3.plot(d3p['x'],d3p['y'], c = color_real)
ax3.plot(C2[:,0], C2[:,1], c = color_point)
ax3.plot(C3[:,0], C3[:,1], c = color_sphere)
ax3.set_title("Take 3")
ax3.add_artist(circle3)
ax3.legend(["Observed trajectory", "Point particle best fit", "Rolling sphere best fit"])

ax4.plot(d4p['x'],d4p['y'], c = color_real)
ax4.plot(D2[:,0], D2[:,1], c = color_point)
ax4.plot(D3[:,0], D3[:,1], c = color_sphere)
ax4.set_title("Take 4")
ax4.add_artist(circle4)
ax4.legend(["Observed trajectory", "Point particle best fit", "Rolling sphere best fit"])

ax1.set_xlim(-kk,kk)
ax1.set_ylim(-kk,kk)
ax2.set_xlim(-kk,kk)
ax2.set_ylim(-kk,kk)
ax3.set_xlim(-kk,kk)
ax3.set_ylim(-kk,kk)
ax4.set_xlim(-kk,kk)
ax4.set_ylim(-kk,kk)
# Out:
# (-0.5, 0.5)
